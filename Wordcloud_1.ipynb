# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn import preprocessing
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd

# %%
# Load The Data

# %%
data = pd.read_csv('train_set.csv', sep="\t")

# %%
df=pd.DataFrame(data)

# %%
ds=df[df['Category']=="Film"]

# %%
film=ds[["Title","Content"]]

# %%
film=film.to_json(force_ascii=False, orient='records').replace('"Title":', '').replace('"Content":', '')

# %%
#Generate a Word Cloud

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color = 'white',mode="RGB",width = 2000, height = 1000).generate(film)
plt.title("Film-text wordcloud")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
#Buisiness

# %%
ds=df[df['Category']=="Business"]

# %%
business=ds[["Title","Content"]]

# %%
business=business.to_json(force_ascii=False, orient='records').replace('"Title":', '').replace('"Content":', '')

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color = 'white',mode="RGB",width = 2000, height = 1000).generate(business)
plt.title("Film-text wordcloud")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3f888181c58a> in <module>()
#       1 plt.figure(figsize=(20,10))
# ----> 2 wordcloud = WordCloud(background_color = 'white',mode="RGB",width = 2000, height = 1000).generate(business)
#       3 plt.title("Film-text wordcloud")
#       4 plt.imshow(wordcloud)
#       5 plt.axis("off")
#
# /home/tasos/anaconda2/lib/python2.7/site-packages/wordcloud/wordcloud.pyc in generate(self, text)
#     569         self
#     570         """
# --> 571         return self.generate_from_text(text)
#     572
#     573     def _check_generated(self):
#
# /home/tasos/anaconda2/lib/python2.7/site-packages/wordcloud/wordcloud.pyc in generate_from_text(self, text)
#     550         self
#     551         """
# --> 552         words = self.process_text(text)
#     553         self.generate_from_frequencies(words)
# ...

# %%
#Politics

# %%
ds=df[df['Category']=="Politics"]

# %%
politics=ds[["Title","Content"]]

# %%
politics=politics.to_json(force_ascii=False, orient='records').replace('"Title":', '').replace('"Content":', '')

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color = 'white',mode="RGB",width = 2000, height = 1000).generate(politics)
plt.title("Film-text wordcloud")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
#Football

# %%
ds=df[df['Category']=="Football"]

# %%
football=ds[["Title","Content"]]

# %%
football=football.to_json(force_ascii=False, orient='records').replace('"Title":', '').replace('"Content":', '')

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color = 'white',mode="RGB",width = 2000, height = 1000).generate(football)
plt.title("Film-text wordcloud")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
#Technology

# %%
ds=df[df['Category']=="Technology"]

# %%
technology=ds[["Title","Content"]]

# %%
technology=technology.to_json(force_ascii=False, orient='records').replace('"Title":', '').replace('"Content":', '')

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color = 'white',mode="RGB",width = 2000, height = 1000).generate(football)
plt.title("Film-text wordcloud")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
